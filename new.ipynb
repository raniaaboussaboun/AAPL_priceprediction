# %%
import yfinance as yf

apple = yf.Ticker("AAPL")
news = apple.news

# %%
import pandas as pd 
news_df = pd.DataFrame(news)

# %%
news_df = news_df[['title', 'publisher', 'link', 'providerPublishTime']]
news_df['providerPublishTime'] = pd.to_datetime(news_df['providerPublishTime'], unit='s')

# %%
news_df.shape
# Out:
# (8, 4)

# %%
news_df.to_csv('apple_news.csv', index=False)

# %%
import requests
import pandas as pd

api_key = '5BKAD6K4HA5ZBPHT'  # Replace with your actual API key

url = 'https://www.alphavantage.co/query'

params = {
    'function': 'NEWS_SENTIMENT',
    'tickers': 'AAPL',
    'apikey': api_key
}

response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    print(data) 

    # Check if 'data' exists in the response
    if 'data' in data:
        articles = data['data']
        news_df = pd.DataFrame(articles)
        print(news_df.head())
    else:
        print("No news data found in the response.")
else:
    print(f"Error fetching data: {response.status_code}, Message: {response.text}")
# Out:
# {'items': '50', 'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish', 'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.', 'feed': [{'title': "Taiwan Semi Founder Calls For New Strategy After Intel Chief's Departure - Intel  ( NASDAQ:INTC ) ", 'url': 'https://www.benzinga.com/24/12/42435733/taiwan-semi-founder-calls-for-new-strategy-after-intel-chiefs-departure', 'time_published': '20241211T132012', 'authors': ['Anusuya Lahiri'], 'summary': "Taiwan Semiconductor Manufacturing Co TSM founder Morris Chang told Reuters Monday that Intel Corp INTC should have focused on developing its artificial intelligence moat instead of contract chipmaking. Chang's comments followed Intel chief Pat Gelsinger's departure after he failed to impress the ...", 'banner_image': 'https://editorial-assets.benzinga.com/wp-content/uploads/2024/12/11034
# ...

# %%
data=articles

# %%
for article in articles:
    if isinstance(article['time_published'], str):
        article['time_published'] = datetime.strptime(article['time_published'], "%Y%m%dT%H%M%S")

df = pd.DataFrame(articles)

print(df[['title', 'url', 'time_published', 'authors', 'summary']])
# Out:
#                                                 title  \
# 0   Taiwan Semi Founder Calls For New Strategy Aft...
# 1   A Tech Renaissance Could Offer Enticing Opport...
# 2   Is Nvidia the Top Artificial Intelligence  ( A...
# 3   Computer Hardware Manufacturing Market Set to ...
# 4   Should Vanguard Russell 1000 Growth ETF  ( VON...
# 5   Should You Invest in the Fidelity MSCI Informa...
# 6   Is Elon Musk Apple TV's 'Slow Horses' Fan? His...
# 7   Tesla Tops Nvidia And Apple In Innovation: Ana...
# 8   Apple Watch Ultra Could Feature Satellite Text...
# 9   HPQ Soars 21% YTD: Should You Buy, Sell or Hol...
# 10  Copa América, Summer Olympics, Donald Trump, P...
# 11  Competitor Analysis: Evaluating Apple And Comp...
# 12  Taiwan Semi November Revenue Ups 34% Strengthe...
# 13  Apple Inc.  ( AAPL )  is Attracting Investor A...
# 14  Want to Buy Nvidia Stock Before the End of the...
# 15               Will the Stock Market Crash in 2025?
# ...

# %%
df.to_csv('news2.csv', index=False)

# %%
import requests
import pandas as pd

api_key = '5BKAD6K4HA5ZBPHT'  # Replace with your actual API key

url = 'https://www.alphavantage.co/query'

params = {
    'function': 'NEWS_SENTIMENT',
    'tickers': 'AAPL',
    'apikey': api_key
}

response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    
    if 'feed' in data:
        articles = data['feed']
        
        news_df = pd.DataFrame(articles)
        
        news_df = news_df[['title', 'url', 'summary', 'source', 'overall_sentiment_label']]
        
        print(news_df.head())
    else:
        print("No news data found in the response.")
else:
    print(f"Error fetching data: {response.status_code}, Message: {response.text}")
# Out:
#                                                title  \
# 0  Taiwan Semi Founder Calls For New Strategy Aft...
# 1  A Tech Renaissance Could Offer Enticing Opport...
# 2  Is Nvidia the Top Artificial Intelligence  ( A...
# 3  Computer Hardware Manufacturing Market Set to ...
# 4  Should Vanguard Russell 1000 Growth ETF  ( VON...
#
#                                                  url  \
# 0  https://www.benzinga.com/24/12/42435733/taiwan...
# 1  https://www.benzinga.com/trading-ideas/long-id...
# 2  https://www.fool.com/investing/2024/12/11/is-n...
# 3  https://www.benzinga.com/pressreleases/24/12/g...
# 4  https://www.zacks.com/stock/news/2381885/shoul...
#
#                                              summary            source  \
# 0  Taiwan Semiconductor Manufacturing Co TSM foun...          Benzinga
# 1  Late last month, JPMorgan analysts stated that...          Benzinga
# 2  Few stocks have done as consistently well as N...       Motley Fool
# ...
